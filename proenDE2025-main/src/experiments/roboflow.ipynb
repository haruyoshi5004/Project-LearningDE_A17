# %%
#download dataset

# %pip install roboflow

from json import load as jsonload
from roboflow import Roboflow

jsonfile : dict
with open("secret.json") as file:
    jsonfile = jsonload(file)

rf = Roboflow(api_key=jsonfile["roboflow"]["api_key"])
project = rf.workspace("2025prode").project("my-first-project-15bl7")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# '/Users/dynamiteopanty/Documents/Programming/bunkyo/2025proDE/My-First-Project-1'
